# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plot

df = pd.read_csv('output.csv',header=None)
print(df.head())
df.shape
plot.figure(figsize=(20,10))
plot.plot(df[22000:24000])
plot.show()
plot.figure(figsize=(20,10))
plot.plot(df[0:24000])
# Out:
#           0   1
# 0  0.000000 NaN
# 1  0.000021 NaN
# 2  0.000082 NaN
# 3  0.000185 NaN
# 4  0.000327 NaN
# ...
