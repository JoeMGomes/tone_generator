# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plot

df = pd.read_csv('output.csv',header=None)
print(df.head())
df.shape
plot.figure(figsize=(20,10))
plot.plot(df[22000:24000])
plot.show()
plot.figure(figsize=(20,10))
plot.plot(df[0:5000])
# Out:
#           0   1
# 0  0.000000 NaN
# 1  0.000012 NaN
# 2  0.000046 NaN
# 3  0.000103 NaN
# 4  0.000183 NaN
# [<matplotlib.lines.Line2D at 0x7f5e044845f8>,
#  <matplotlib.lines.Line2D at 0x7f5e04484710>]
